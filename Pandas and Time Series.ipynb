# %%
import pandas as pd
import numpy as np

df=pd.read_csv(r"D:\Self Study\Datasets\pokemon_data.csv")

# %%
print(df.head(3))
print(df.tail(3))
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df["Attack"][100]
# Out:
# 50

# %%
df[["Name","Generation"]]
# Out:
#                       Name  Generation
# 0                Bulbasaur           1
# 1                  Ivysaur           1
# 2                 Venusaur           1
# 3    VenusaurMega Venusaur           1
# 4               Charmander           1
# ..                     ...         ...
# 795                Diancie           6
# 796    DiancieMega Diancie           6
# 797    HoopaHoopa Confined           6
# 798     HoopaHoopa Unbound           6
# 799              Volcanion           6
#
# [800 rows x 2 columns]

# %%
df.iloc[0:5]
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.iloc[2,1]
# Out:
# 'Venusaur'

# %%
for index,row in df.iterrows():
    print(index,row[["Name","Attack"]])
# Out:
# 0 Name      Bulbasaur
# Attack           49
# Name: 0, dtype: object
# 1 Name      Ivysaur
# Attack         62
# Name: 1, dtype: object
# 2 Name      Venusaur
# Attack          82
# Name: 2, dtype: object
# 3 Name      VenusaurMega Venusaur
# Attack                      100
# Name: 3, dtype: object
# 4 Name      Charmander
# Attack            52
# Name: 4, dtype: object
# 5 Name      Charmeleon
# Attack            64
# Name: 5, dtype: object
# 6 Name      Charizard
# Attack           84
# Name: 6, dtype: object
# 7 Name      CharizardMega Charizard X
# Attack                          130
# Name: 7, dtype: object
# 8 Name      CharizardMega Charizard Y
# Attack                          104
# Name: 8, dtype: object
# 9 Name      Squirtle
# Attack          48
# Name: 9, dtype: object
# 10 Name      Wartortle
# Attack           63
# Name: 10, dtype: object
# 11 Name      Blastoise
# Attack           83
# Name: 11, dtype: object
# 12 Name      BlastoiseMega Blastoise
# ...

# %%
df.loc[df["Type 1"]=="Fire" ]
# Out:
#        #                       Name Type 1    Type 2   HP  Attack  Defense  \
# 4      4                 Charmander   Fire       NaN   39      52       43
# 5      5                 Charmeleon   Fire       NaN   58      64       58
# 6      6                  Charizard   Fire    Flying   78      84       78
# 7      6  CharizardMega Charizard X   Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y   Fire    Flying   78     104       78
# 42    37                     Vulpix   Fire       NaN   38      41       40
# 43    38                  Ninetales   Fire       NaN   73      76       75
# 63    58                  Growlithe   Fire       NaN   55      70       45
# 64    59                   Arcanine   Fire       NaN   90     110       80
# 83    77                     Ponyta   Fire       NaN   50      85       55
# 84    78                   Rapidash   Fire       NaN   65     100       70
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ts=pd.read_csv(r"D:\Self Study\Datasets\ETH_1h.csv")

# %%
ts.head(4)
# Out:
#                Date  Symbol    Open    High     Low   Close      Volume
# 0  2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1  2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2  2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3  2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92

# %%
ts.loc[0,"Date"]
# Out:
# '2020-03-13 08-PM'

# %%
ts.loc[0,"Date"].date_name()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-c25ebceef23e> in <module>
# ----> 1 ts.loc[0,"Date"].date_name()
#
# AttributeError: 'str' object has no attribute 'date_name'

# %%
ts["Date"]=pd.to_datetime(ts["Date"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# D:\Data Science Tools\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1857         try:
# -> 1858             values, tz_parsed = conversion.datetime_to_datetime64(data)
#    1859             # If tzaware, these values represent unix timestamps, so we
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ParserError                               Traceback (most recent call last)
# <ipython-input-7-2b904406b54b> in <module>
# ----> 1 ts["Date"]=pd.to_datetime(ts["Date"])
#
# ...

# %%
d_format='%Y-%m-%d %I-%p'

# %%
ts["Date"]=pd.to_datetime(ts["Date"],format=d_format)

# %%
ts.head(1)
# Out:
#                  Date  Symbol    Open    High     Low   Close      Volume
# 0 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93

# %%
ts.loc[0,"Date"].day_name()
# Out:
# 'Friday'

# %%
ts["Date"].dt.day_name()
# Out:
# 0          Friday
# 1          Friday
# 2          Friday
# 3          Friday
# 4          Friday
#            ...
# 23669    Saturday
# 23670    Saturday
# 23671    Saturday
# 23672    Saturday
# 23673    Saturday
# Name: Date, Length: 23674, dtype: object

# %%
ts["Day of week"]=ts["Date"].dt.day_name()

# %%
ts.head(3)
# Out:
#                  Date  Symbol    Open    High     Low   Close      Volume  \
# 0 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
#
#   Day of week
# 0      Friday
# 1      Friday
# 2      Friday

# %%
ts["Date"].min()
# Out:
# Timestamp('2017-07-01 11:00:00')

# %%
ts["Date"].max()
# Out:
# Timestamp('2020-03-13 20:00:00')

# %%
ts["Date"].max()-ts["Date"].min()
# Out:
# Timedelta('986 days 09:00:00')

# %%
x=ts["Day of week"]
fig = plt.figure()

y=ts["Close"]

plt.figure(figsize=(8,4))
# Out:
# <BarContainer object of 23674 artists>
